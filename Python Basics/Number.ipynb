# %%
base=10
height=7
area=( base*height)/2
print(area)
# Out:
# 35.0

# %%
type(area)
# Out:
# float

# %%
type(100.56)
# Out:
# float

# %%
x=10
y=3
x+y
# Out:
# 13

# %%
x-y
# Out:
# 7

# %%
x/y
# Out:
# 3.3333333333333335

# %%
x,y
# Out:
# (10, 3)

# %%
x%y
# Out:
# 1

# %%
x**y
# Out:
# 1000

# %%
10+2*6
# Out:
# 22

# %%
(10+2)*6
# Out:
# 72

# %%
foo=2.3e4
foo
# Out:
# 23000.0

# %%
1e4
# Out:
# 10000.0

# %%
bar=2.3e-3

# %%
1e-3
# Out:
# 0.001

# %%
bar
# Out:
# 0.0023

# %%
food=120.34
rent=500.5
utilities = 200.4

# %%
total =food+rent+utilities
total
# Out:
# 821.24

# %%
round(total)
# Out:
# 821

# %%
#The round() function in Python is used to round a number to the nearest value.
# Parameters:
# number → the value you want to round
# digits → optional, how many decimal places you want

round(total,1)
# Out:
# 821.2

# %%
# If you give negative digits, Python rounds before the decimal.
round(1234, -1)
# Out:
# 1230

# %%
round(1234, -2)
# Out:
# 1200

# %%
round(2.5)
# Out:
# 2

# %%
round(3.5)

# Reason:
# Python rounds to the nearest even number.
# Out:
# 4

# %%
food="120.34"
rent="500.67"
total=float(food) + float(rent)
total
# Out:
# 621.01

# %%
type(food)
# Out:
# str

# %%
type(float(food))
# Out:
# float

# %%
import math
x=16
math.sqrt(x)
# Out:
# 4.0

# %%
math.floor(3.7)
# Out:
# 3

# %%
math.ceil(3.7)
# Out:
# 4

# %%
math.pi
# Out:
# 3.141592653589793

# %%
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fma',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
# binary
format(5,'b')
# Out:
# '101'

# %%
# octal
format(8,'o')
# Out:
# '10'

# %%
# hexadecimal
format(255,'x')
# Out:
# 'ff'

# %%
# decimal
format(10,'d')
# Out:
# '10'
