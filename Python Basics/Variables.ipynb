# %%
name="Satwik"
name
# Out:
# 'Satwik'

# %%
age=22
age
# Out:
# 22

# %%
_salary=10000
print(_salary)
# Out:
# 10000

# %%
type(age)
# Out:
# int

# %%
fname=name

# %%
fname
# Out:
# 'Satwik'

# %%
name="yogesh"
name
# Out:
# 'yogesh'

# %%
fname
# Out:
# 'Satwik'

# %%
type(fname)
type(name)
id(name)
# Out:
# 2361768073696

# %%
id(fname)
# Out:
# 2361768068944

# %%
lname=fname

# %%
lname
# Out:
# 'Satwik'

# %%
id(lname)
# Out:
# 2361768068944
