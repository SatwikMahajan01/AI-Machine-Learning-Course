# %%
first='Satwik'
lname='Mahajan'

# %%
type (first)
# Out:
# str

# %%
name=first+" "+lname
name
# Out:
# 'Satwik Mahajan'

# %%
name= f"{first} {lname}"
name
# Out:
# 'Satwik Mahajan'

# %%
age=22
info= f"{first} {lname} is {age} year old"
info
# Out:
# 'Satwik Mahajan is 22 year old'

# %%
name
# Out:
# 'Satwik Mahajan'

# %%
name[0]
# Out:
# 'S'

# %%
 name[0:6]
# Out:
# 'Satwik'

# %%
name[7:]
# Out:
# 'Mahajan'

# %%
name[-1]
# Out:
# 'n'

# %%
len(name)
# Out:
# 14

# %%
 # strings are immutable
# name[0]='C'--> will not work

# %%
food_story="Satwik's faviourite food is basundi"
msg='He said "opps!"'

# %%
food_story
# Out:
# "Satwik's faviourite food is basundi"

# %%
msg
# Out:
# 'He said "opps!"'

# %%
recipe='''
Veg Biryani with saffron, cardamom,
and cloves, granished with friend
onions and cilantro
'''

# %%
food_story
# Out:
# '\nVeg Biryani with saffron, cardamon,\nand cloves, granished with friend\nonions and cilantro\n'

# %%
print(food_story)
# Out:
# Veg Biryani with saffron, cardamon,
# and cloves, granished with friend
# onions and cilantro

# %%
spices="cardamom"
spices in recipe
# Out:
# True

# %%
"milk" in recipe
# Out:
# False

# %%
recipe.find(spices)
# Out:
# 27

# %%
recipe.find("Veg")
# Out:
# 1

# %%
s="Patient was charged 100$ for lab test"
s
# Out:
# 'Patient was charged 100$ for lab test'

# %%
s=s.replace("100$", "10$")

# %%
s
# Out:
# 'Patient was charged 10$ for lab test'

# %%
s.upper()
# Out:
# 'PATIENT WAS CHARGED 10$ FOR LAB TEST'

# %%
s.lower()
# Out:
# 'patient was charged 10$ for lab test'

# %%
s.index("10$")
# Out:
# 20

# %%
s="satwik mahajan"
s.count("a")
# Out:
# 4

# %%
result='18'.isdigit();
result
# Out:
# True

# %%
text="my age is: "
age=22
text+ str(age)
# Out:
# 'my age is: 22'

# %%
s="hey\tbro"
s
# Out:
# 'hey\tbro'

# %%
print(s)
# Out:
# hey	bro

# %%
tickers="AAPLE|NVDI|GOOGLE|CHATGPT"
tickers.split("|")
# Out:
# ['AAPLE', 'NVDI', 'GOOGLE', 'CHATGPT']

# %%
tickers.split("|", maxsplit=2)
# Out:
# ['AAPLE', 'NVDI', 'GOOGLE|CHATGPT']

# %%
data="   hey, we have to go there, you coming der?     "
data
# Out:
# '   hey, we have to go there, you coming der?     '

# %%
data.strip()
# Out:
# 'hey, we have to go there, you coming der?'

# %%
file_name="report.pdf"
file_name.endswith(".pdf")
# Out:
# True

# %%
help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to 'utf-8'.
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getitem__(self, key, /)
# ...

# %%
string="satwik"
string.zfill(10)
# Out:
# '0000satwik'

# %%
string.title()
# Out:
# 'Satwik'

# %%
string.swapcase()
# Out:
# 'SATWIK'

# %%
string.startswith("s")
# Out:
# True

# %%
text = "Line1\nLine2\rLine3\r\nLine4"

print(text.splitlines())
# Out:
# ['Line1', 'Line2', 'Line3', 'Line4']
