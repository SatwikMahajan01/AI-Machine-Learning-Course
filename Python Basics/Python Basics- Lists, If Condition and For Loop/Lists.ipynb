# %%
items= ["Bread","Pasta","Mangoes","Chocolates"]

# %%
items
# Out:
# ['Bread', 'Pasta', 'Mangoes', 'Chocolates']

# %%
items[:2]
# Out:
# ['Bread', 'Pasta']

# %%
items[-1]
# Out:
# 'Chocolates'

# %%
items.append('Butter')
items
# Out:
# ['Bread', 'Pasta', 'Mangoes', 'Chocolates', 'Butter']

# %%
items.remove('Butter')
items
# Out:
# ['Bread', 'Pasta', 'Mangoes', 'Chocolates']

# %%
items.insert(1,'Butter')
items
# Out:
# ['Bread', 'Butter', 'Pasta', 'Mangoes', 'Chocolates']

# %%
items[1]='cheese'
items
# Out:
# ['Bread', 'cheese', 'Pasta', 'Mangoes', 'Chocolates']

# %%
items[3:] = ['almonds']
items
# Out:
# ['Bread', 'cheese', 'a', 'almonds']

# %%
# items[2:]='almonds'
# items
# Out:
# ['Bread', 'cheese', 'a', 'l', 'm', 'o', 'n', 'd', 's']

# %%
'rice' in items
# Out:
# False

# %%
expenses=[20,100,45,300]
expenses.sort()
expenses
# Out:
# [20, 45, 100, 300]

# %%
expenses.sort(reverse=True)
expenses
# Out:
# [300, 100, 45, 20]

# %%
food_items=['banana','pasta','chocolates','grapes']
bathroom_items=["shampoo","soap"]
items=food_items + bathroom_items
items
# Out:
# ['banana', 'pasta', 'chocolates', 'grapes', 'shampoo', 'soap']

# %%
len(items)
# Out:
# 6

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
items
# Out:
# ['banana', 'pasta', 'chocolates', 'grapes', 'shampoo', 'soap']

# %%
items.reverse()
print(items)
# Out:
# ['soap', 'shampoo', 'grapes', 'chocolates', 'pasta', 'banana']

# %%
print(items[::-1]) # using slicing
# Out:
# ['banana', 'pasta', 'chocolates', 'grapes', 'shampoo', 'soap']

# %%
items.pop()
# Out:
# 'banana'

# %%
# count() must have an argument
fruits = ["apple", "banana", "apple", "orange"]
print(fruits.count("apple"))
# Out:
# 2

# %%
fruits.clear()
fruits
# Out:
# []

# %%
items = [1, 2, 3]
more_items = [4, 5, 6]
items.extend(more_items)
print(items)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
numbers = [10, 20]
numbers.extend((30, 40))
print(numbers)
# Out:
# [10, 20, 30, 40]

# %%
# append(x)  → add x as one element
# extend(x)  → add elements of x individually
